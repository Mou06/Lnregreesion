# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("Book1 2.csv") # import data
df # show data
# Out:
#        x           y
# 0     24   21.549452
# 1     50   47.464463
# 2     15   17.218656
# 3     38   36.586398
# 4     87   87.288984
# 5     36   32.463875
# 6     12   10.780897
# 7     81   80.763399
# 8     25   24.612151
# 9      5    6.963319
# 10    16   11.237573
# 11    16   13.532902
# 12    24   24.603239
# 13    39   39.400500
# 14    54   48.437538
# 15    60   61.699003
# 16    26   26.928324
# 17    73   70.405206
# 18    29   29.340924
# 19    31   25.308952
# 20    68   69.029343
# 21    87   84.994847
# 22    58   57.043103
# 23    54   50.592199
# 24    84   83.027722
# 25    58   57.057527
# 26    49   47.958833
# 27    20   24.342264
# 28    90   94.684883
# 29    48   48.039707
# ..   ...         ...
# 670   84   82.889358
# 671   64   63.613650
# 672   12   11.296272
# 673   61   60.022749
# 674   75   72.603393
# 675   15   11.879646
# 676  100  100.701274
# 677   43   45.124208
# 678   13   14.811068
# 679   48   48.093680
# 680   45   42.291457
# ...

# %%
df.shape #show shape of data
# Out:
# (700, 2)

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(df.x,df.y,color='red',marker='*')

# %%
X=pd.DataFrame(df['x']) # concatenate dataframe along with row and column 
Y=pd.DataFrame(df['y'])

# %%
lm=linear_model.LinearRegression() #linear regression function

# %%
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.predict([[79]])
# Out:
# array([[79.15910803]])
